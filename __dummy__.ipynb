# %% [markdown]
# Adding a Post detail screen and wiring up navigation from the list items.

# %% [markdown]
# Now I’ll add `PostDetailScreen` and modify `PostsListScreen` so tapping an item navigates to it and passes the `Post` object.
